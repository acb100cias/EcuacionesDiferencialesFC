# %%
from numpy import *
from matplotlib.pyplot import*

# %%
h=0.1
sigma=2.3
y0=2.3
x0=0.5
ro=0.2
z0=1.4
beta=0.9
for i in range(15000):
    x1=h*(sigma*(y0-x0))+x0
    y1=h*(x0*(ro-z0)-y0)+y0
    z1=h*(x0*y0-beta*z0)+z0
    x0=x1
    y0=y1
    z0=z1
    if z1>30: 
        print(x1,y1)
    else:
        print('hola')
# Out:
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# ...
